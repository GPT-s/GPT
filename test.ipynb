# %%
print('hello word')
# Out:
# hello word

# %% [markdown]
# 텍스트모드:기록형태모드 셀로 만들고싶을때 사용

# %% [markdown]
# 실행단축키
# 1.ctrl+enter: 단순히 실행
# 2.shift+enter: 실행 후에 커서를 다음셀로 이동
# 3.alt+enter:셀 실행후에 아래 셀을 추가해줌

# %% [markdown]
# 변수:데이터를 담을 수 있는 공간

# %%
#num에2 넣어주기
#주석처리

num=2

# %%
num
# Out:
# 2

# %%
num=5

# %%
num
# Out:
# 5

# %%
#문자열 변수에 담아주기
s1="안녕하세요 저는 장예지입니다"

# %%
s1
# Out:
# '안녕하세요 저는 장예지입니다'

# %%
s2='파이썬에서는 큰따옴표나 작은따옴표나 차이가 없다'
s2
# Out:
# '파이썬에서는 큰따옴표나 작은따옴표나 차이가 없다'

# %%
s3='she\'s gone'

s3
# Out:
# "she's gone"

# %%
yd_info='2022 0313 sunny'
print(yd_info[0:4])
print(yd_info[5:9])
print(yd_info[10:15])
# Out:
# 2022
# 0313
# sunny

# %%
month=11
day=18
s=f'오늘은{month}월 {day}일 입니다'
s
# Out:
# '오늘은11월 18일 입니다'

# %%
x=100
y=200
add=x+y
print(f'{x}와 {y}의 합은 {add}입니다')
# Out:
# 100와 200의 합은 300입니다

# %%
print('오늘뭐먹지')
# Out:
# 오늘뭐먹지

# %%
Today='2022년 11월 18일'
Today
# Out:
# '2022년 11월 18일'

# %%
num1=23
num2=3
print(f'더하기결과:{num1+num2}')
print(f'빼기결과:{num1-num2}')
print(f'곱하기결과:{num1*num2}')
print(f'나누기결과:{num1/num2}')
# Out:
# 더하기결과:26
# 빼기결과:20
# 곱하기결과:69
# 나누기결과:7.666666666666667

# %%
num1=int(input('첫번째 정수를 입력해 주세요>>'))
num2=int(input('두번째 정수를 입력해 주세요>>'))
print(f'더하기결과:{num1+num2}')
print(f'빼기결과:{num1-num2}')
print(f'곱하기결과:{num1*num2}')
print(f'나누기결과:{num1/num2}')
# Out:
# 첫번째 정수를 입력해 주세요>>23
# 두번째 정수를 입력해 주세요>>3
# 더하기결과:26
# 빼기결과:20
# 곱하기결과:69
# 나누기결과:7.666666666666667

# %%
money=9000
if money>=10000:
  print("택시를 탄다")
else :
  print('버스를 탄다')
# Out:
# 버스를 탄다

# %%
name_list['영식','상철','영호']
name=input('이름을 입력하세요:')
 if name in "영식":
   print(name_list"님 안녕하세요")
# Out:
#   File "<ipython-input-8-2ebc9c231c4f>", line 3
#     if name in "영식":
#     ^
# IndentationError: unexpected indent
